# %% [markdown]
# <a href="https://colab.research.google.com/github/joncalle/AnalToolsDecMrk/blob/main/DataBreach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount("/content/drive", force_remount = True)
project_dir = "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Nueva sección

# %%
df = pd.read_excel(project_dir+"/Final Project_Data Breach.xlsx")

# %%
df.head()
# Out:
#                     Source.Name  Assigned Breach Number Date Reported To OCA  \
# 0  Data Breach Web Report  2020                   16279           2020-01-02
# 1  Data Breach Web Report  2020                   16280           2020-01-02
# 2  Data Breach Web Report  2020                   16281           2020-01-02
# 3  Data Breach Web Report  2020                   16282           2020-01-02
# 4  Data Breach Web Report  2020                   16283           2020-01-02
#
#             Organization Name Breach Type Description  \
# 0  North Shore Medical Center              Electronic
# 1                 Savers Bank              Electronic
# 2             Mutual One Bank              Electronic
# 3            Main Street Bank              Electronic
# 4            Main Street Bank              Electronic
#
#   Breach Occur at the Reporting Entity?  MA Residents Affected SSNBreached  \
# 0                                   Yes                    1.0         Yes
# 1                                   NaN                    1.0         NaN
# 2                                   NaN                    1.0         NaN
# 3                                   NaN                    1.0         NaN
# 4                                   NaN                    1.0         NaN
#
#   Account Number Breached Drivers Licenses Breached  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#   Credit Debit Numbers Breached Provided Credit Monitoring  Data Encrypted  \
# 0                           NaN                        Yes             NaN
# 1                           Yes                        NaN             NaN
# 2                           Yes                        NaN             NaN
# 3                           Yes                        NaN             NaN
# 4                           Yes                        NaN             NaN
#
#   Mobile Device Lost Stolen
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
df.describe()
# Out:
#        Assigned Breach Number  MA Residents Affected  Data Encrypted
# count            14422.000000           1.433700e+04             0.0
# mean             16812.183470           6.839853e+02             NaN
# std               5828.519266           2.757004e+04             NaN
# min               8405.000000           0.000000e+00             NaN
# 25%              12018.250000           1.000000e+00             NaN
# 50%              15852.500000           3.000000e+00             NaN
# 75%              20428.750000           1.600000e+01             NaN
# max              28857.000000           2.982421e+06             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14422 entries, 0 to 14421
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Source.Name                            14422 non-null  object
#  1   Assigned Breach Number                 14422 non-null  int64
#  2   Date Reported To OCA                   14422 non-null  datetime64[ns]
#  3   Organization Name                      14422 non-null  object
#  4   Breach Type Description                14393 non-null  object
#  5   Breach Occur at the Reporting Entity?  8049 non-null   object
#  6   MA Residents Affected                  14337 non-null  float64
#  7   SSNBreached                            6777 non-null   object
#  8   Account Number Breached                4257 non-null   object
#  9   Drivers Licenses Breached              2107 non-null   object
#  10  Credit Debit Numbers Breached          6185 non-null   object
#  11  Provided Credit Monitoring             8059 non-null   object
#  12  Data Encrypted                         0 non-null      float64
#  13  Mobile Device Lost Stolen              126 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(10)
# memory usage: 1.5+ MB

# %%
df.isna().sum()
# Out:
# Source.Name                                  0
# Assigned Breach Number                       0
# Date Reported To OCA                         0
# Organization Name                            0
# Breach Type Description                     29
# Breach Occur at the Reporting Entity?     6373
# MA Residents Affected                       85
# SSNBreached                               7645
# Account Number Breached                  10165
# Drivers Licenses Breached                12315
# Credit Debit Numbers Breached             8237
# Provided Credit Monitoring                6363
# Data Encrypted                           14422
# Mobile Device Lost Stolen                14296
# dtype: int64

# %%
df.dtypes
# Out:
# Source.Name                                      object
# Assigned Breach Number                            int64
# Date Reported To OCA                     datetime64[ns]
# Organization Name                                object
# Breach Type Description                          object
# Breach Occur at the Reporting Entity?            object
# MA Residents Affected                           float64
# SSNBreached                                      object
# Account Number Breached                          object
# Drivers Licenses Breached                        object
# Credit Debit Numbers Breached                    object
# Provided Credit Monitoring                       object
# Data Encrypted                                  float64
# Mobile Device Lost Stolen                        object
# dtype: object

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14417    False
# 14418    False
# 14419    False
# 14420    False
# 14421    False
# Length: 14422, dtype: bool

# %%
df['Reported_Year'] = pd.DatetimeIndex(df['Date Reported To OCA']).year

# %%
df.head()
# Out:
#                     Source.Name  Assigned Breach Number Date Reported To OCA  \
# 0  Data Breach Web Report  2020                   16279           2020-01-02
# 1  Data Breach Web Report  2020                   16280           2020-01-02
# 2  Data Breach Web Report  2020                   16281           2020-01-02
# 3  Data Breach Web Report  2020                   16282           2020-01-02
# 4  Data Breach Web Report  2020                   16283           2020-01-02
#
#             Organization Name Breach Type Description  \
# 0  North Shore Medical Center              Electronic
# 1                 Savers Bank              Electronic
# 2             Mutual One Bank              Electronic
# 3            Main Street Bank              Electronic
# 4            Main Street Bank              Electronic
#
#   Breach Occur at the Reporting Entity?  MA Residents Affected SSNBreached  \
# 0                                   Yes                    1.0         Yes
# 1                                   NaN                    1.0         NaN
# 2                                   NaN                    1.0         NaN
# 3                                   NaN                    1.0         NaN
# 4                                   NaN                    1.0         NaN
#
#   Account Number Breached Drivers Licenses Breached  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#   Credit Debit Numbers Breached Provided Credit Monitoring  Data Encrypted  \
# 0                           NaN                        Yes             NaN
# 1                           Yes                        NaN             NaN
# 2                           Yes                        NaN             NaN
# 3                           Yes                        NaN             NaN
# 4                           Yes                        NaN             NaN
#
#   Mobile Device Lost Stolen  Reported_Year
# 0                       NaN           2020
# 1                       NaN           2020
# 2                       NaN           2020
# 3                       NaN           2020
# 4                       NaN           2020

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.head()
# Out:
#                     Source.Name  Assigned_Breach_Number Date_Reported_To_OCA  \
# 0  Data Breach Web Report  2020                   16279           2020-01-02
# 1  Data Breach Web Report  2020                   16280           2020-01-02
# 2  Data Breach Web Report  2020                   16281           2020-01-02
# 3  Data Breach Web Report  2020                   16282           2020-01-02
# 4  Data Breach Web Report  2020                   16283           2020-01-02
#
#             Organization_Name Breach_Type_Description  \
# 0  North Shore Medical Center              Electronic
# 1                 Savers Bank              Electronic
# 2             Mutual One Bank              Electronic
# 3            Main Street Bank              Electronic
# 4            Main Street Bank              Electronic
#
#   Breach_Occur_at_the_Reporting_Entity?  MA_Residents_Affected SSNBreached  \
# 0                                   Yes                    1.0         Yes
# 1                                   NaN                    1.0         NaN
# 2                                   NaN                    1.0         NaN
# 3                                   NaN                    1.0         NaN
# 4                                   NaN                    1.0         NaN
#
#   Account_Number_Breached Drivers_Licenses_Breached  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#   Credit_Debit_Numbers_Breached Provided_Credit_Monitoring  Data_Encrypted  \
# 0                           NaN                        Yes             NaN
# 1                           Yes                        NaN             NaN
# 2                           Yes                        NaN             NaN
# 3                           Yes                        NaN             NaN
# 4                           Yes                        NaN             NaN
#
#   Mobile_Device_Lost_Stolen  Reported_Year
# 0                       NaN           2020
# 1                       NaN           2020
# 2                       NaN           2020
# 3                       NaN           2020
# 4                       NaN           2020

# %%
plt.figure(figsize=(7,5))
ax=sns.countplot(x=df.Breach_Type_Description)
for container in ax.containers:
    ax.bar_label(container)
plt.xlabel('Breach Type Description')
plt.title('Breach Type')
plt.show()

# %%
plt.figure(figsize=(7,5))
groupedvalues = df.groupby('Reported_Year').count().reset_index()
ax = sns.barplot(x='Reported_Year', y='MA_Residents_Affected',
                 data=groupedvalues,
                 errwidth=0)
ax.bar_label(ax.containers[0])
plt.xlabel('Reported Year')
plt.ylabel('Residents Affected')
plt.title('Residents Affected per year')
plt.show()
